# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='/content/Google_Stock_Price_Train.csv'
training_data=pd.read_csv(url)
training_data.shape
# Out:
# (1258, 6)

# %%
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
# Out:
# (1258, 1)

# %%
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
#getting the inputs and outputs
x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
#reshaping
x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
#importing keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 2s 4ms/step - loss: 0.2077
# Epoch 2/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1521
# Epoch 3/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1180
# Epoch 4/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0996
# Epoch 5/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0903
# Epoch 6/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0856
# Epoch 7/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0832
# Epoch 8/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0814
# Epoch 9/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0798
# Epoch 10/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0783
# Epoch 11/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0766
# Epoch 12/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0750
# Epoch 13/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0733
# Epoch 14/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0716
# Epoch 15/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0699
# Epoch 16/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0680
# Epoch 17/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0662
# Epoch 18/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0642
# Epoch 19/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0623
# Epoch 20/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0604
# Epoch 21/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0583
# Epoch 22/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0562
# Epoch 23/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0541
# Epoch 24/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0519
# Epoch 25/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0497
# Epoch 26/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0474
# Epoch 27/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0452
# Epoch 28/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0429
# Epoch 29/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0406
# Epoch 30/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0382
# Epoch 31/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0359
# Epoch 32/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 33/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0313
# Epoch 34/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0290
# Epoch 35/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0267
# Epoch 36/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0245
# Epoch 37/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0224
# Epoch 38/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 39/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0184
# Epoch 40/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 42/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0131
# Epoch 43/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 46/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 47/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 49/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 52/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 53/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 54/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 55/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 56/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 57/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 58/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 59/200
# 40/40 [==============================] - 0s 6ms/step - loss: 8.8516e-04
# Epoch 60/200
# 40/40 [==============================] - 0s 6ms/step - loss: 7.6896e-04
# Epoch 61/200
# 40/40 [==============================] - 0s 6ms/step - loss: 6.8036e-04
# Epoch 62/200
# 40/40 [==============================] - 0s 5ms/step - loss: 6.1363e-04
# Epoch 63/200
# 40/40 [==============================] - 0s 5ms/step - loss: 5.6115e-04
# Epoch 64/200
# 40/40 [==============================] - 0s 4ms/step - loss: 5.2270e-04
# Epoch 65/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.9032e-04
# Epoch 66/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.6690e-04
# Epoch 67/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.4887e-04
# Epoch 68/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.3594e-04
# Epoch 69/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.2596e-04
# Epoch 70/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.1870e-04
# Epoch 71/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.1346e-04
# Epoch 72/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.0764e-04
# Epoch 73/200
# 40/40 [==============================] - 0s 3ms/step - loss: 4.0339e-04
# Epoch 74/200
# 40/40 [==============================] - 0s 3ms/step - loss: 4.0149e-04
# Epoch 75/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9880e-04
# Epoch 76/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9698e-04
# Epoch 77/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9497e-04
# Epoch 78/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9310e-04
# Epoch 79/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9211e-04
# Epoch 80/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.8953e-04
# Epoch 81/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8808e-04
# Epoch 82/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8585e-04
# Epoch 83/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8504e-04
# Epoch 84/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8403e-04
# Epoch 85/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8137e-04
# Epoch 86/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.7982e-04
# Epoch 87/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.7807e-04
# Epoch 88/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7642e-04
# Epoch 89/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7447e-04
# Epoch 90/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.7208e-04
# Epoch 91/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7152e-04
# Epoch 92/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7019e-04
# Epoch 93/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6795e-04
# Epoch 94/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.6666e-04
# Epoch 95/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.6544e-04
# Epoch 96/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6447e-04
# Epoch 97/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6203e-04
# Epoch 98/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.5988e-04
# Epoch 99/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.5803e-04
# Epoch 100/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.5739e-04
# Epoch 101/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.5589e-04
# Epoch 102/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.5450e-04
# Epoch 103/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.5293e-04
# Epoch 104/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4946e-04
# Epoch 105/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4862e-04
# Epoch 106/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4670e-04
# Epoch 107/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4639e-04
# Epoch 108/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4404e-04
# Epoch 109/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4210e-04
# Epoch 110/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4072e-04
# Epoch 111/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3765e-04
# Epoch 112/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3931e-04
# Epoch 113/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3680e-04
# Epoch 114/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3392e-04
# Epoch 115/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3180e-04
# Epoch 116/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2990e-04
# Epoch 117/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2803e-04
# Epoch 118/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2696e-04
# Epoch 119/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2768e-04
# Epoch 120/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2775e-04
# Epoch 121/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2267e-04
# Epoch 122/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2151e-04
# Epoch 123/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.2031e-04
# Epoch 124/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1890e-04
# Epoch 125/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1742e-04
# Epoch 126/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.1667e-04
# Epoch 127/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1543e-04
# Epoch 128/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1607e-04
# Epoch 129/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.1116e-04
# Epoch 130/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1108e-04
# Epoch 131/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0982e-04
# Epoch 132/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0601e-04
# Epoch 133/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1137e-04
# Epoch 134/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0505e-04
# Epoch 135/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0349e-04
# Epoch 136/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0384e-04
# Epoch 137/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.0198e-04
# Epoch 138/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0032e-04
# Epoch 139/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0025e-04
# Epoch 140/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.9803e-04
# Epoch 141/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.9598e-04
# Epoch 142/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9496e-04
# Epoch 143/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.9662e-04
# Epoch 144/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.9286e-04
# Epoch 145/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9391e-04
# Epoch 146/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9119e-04
# Epoch 147/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.8869e-04
# Epoch 148/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.8865e-04
# Epoch 149/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.8776e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.8938e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.8662e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.8468e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.8597e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.8280e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.8256e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.8388e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.8352e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.8463e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.8173e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.8043e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7995e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7877e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7551e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7976e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7674e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7374e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7782e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7220e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7413e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7231e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7176e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8061e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7069e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7002e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7697e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6794e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6850e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6563e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6957e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6593e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6520e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6945e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6615e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6558e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6670e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6357e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6604e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6666e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6156e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6319e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6299e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6709e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6237e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6384e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6507e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6175e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5968e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6089e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6049e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6300e-04

# %%
#getting the real and importing the testing dataset
url='/content/Google_Stock_Price_Test.csv'
test_data = pd.read_csv(url)
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)
predicted_stock_price
# Out:
# 1/1 [==============================] - 0s 212ms/step
# array([[774.6483 ],
#        [783.0719 ],
#        [781.06824],
#        [789.10657],
#        [798.7573 ],
#        [800.01355],
#        [797.5509 ],
#        [799.39435],
#        [799.6869 ],
#        [799.3427 ],
#        [798.24915],
#        [797.65424],
#        [799.1963 ],
#        [799.4889 ],
#        [812.3302 ],
#        [818.498  ],
#        [825.33746],
#        [822.7563 ],
#        [805.8384 ],
#        [790.49976]], dtype=float32)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016
url='/content/Google_Stock_Price_Train.csv'
training_data = pd.read_csv(url)
training_data.shape
# Out:
# (1258, 6)

# %%
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
# Out:
# (1258, 1)

# %%
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# getting the predicted stock price of 2012-2016

predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)
# Out:
# 40/40 [==============================] - 0s 1ms/step

# %%
# visualizing the whole training data results

plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# Evaluating the RNN model

import math

from sklearn.metrics import mean_squared_error
real_stock_price = [740.3]  # Actual values
predicted_stock_price = [298.09]  # Predicted values


rmse = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))

print(rmse)
# Out:
# 442.21
